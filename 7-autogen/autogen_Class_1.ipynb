# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv  
import os

# %%
token = os.getenv("GITHUB_TOKEN")
endpoint = "https://models.github.ai/inference"
model = "gpt-4.1-mini"

# %%
model_client = OpenAIChatCompletionClient(
    model=model,
    api_key=token,
    base_url=endpoint
)

# %%
agent_1= AssistantAgent(name="my_assistant", model_client=model_client)

# %%
result = await agent_1.run(task="Write a short poem about the sea.")

# %%
print(result)
# Out:
# messages=[TextMessage(id='b07b6a15-d3c3-41dd-ae25-993efc2891da', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 11, 5, 12, 18, 59, 629, tzinfo=datetime.timezone.utc), content='Write a short poem about the sea.', type='TextMessage'), TextMessage(id='ab41cd3a-59bd-496e-b45b-c213e81c0527', source='my_assistant', models_usage=RequestUsage(prompt_tokens=44, completion_tokens=61), metadata={}, created_at=datetime.datetime(2025, 11, 5, 12, 19, 3, 47343, tzinfo=datetime.timezone.utc), content="The sea whispers tales untold,  \nOf depths where dreams and secrets hold.  \nWaves dance under the moon's soft gleam,  \nA timeless song, a liquid dream.  \n\nEndless blue, both wild and free,  \nThe heart's echo in the sea.  \n\nTERMINATE", type='TextMessage')] stop_reason=None
